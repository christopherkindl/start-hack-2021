# %% [markdown]
# # Hourly Time Series Forecasting using XGBoost
#
# [If you haven't already first check out my previous notebook forecasting on the same data using Prophet](https://www.kaggle.com/robikscube/hourly-time-series-forecasting-with-prophet)
#
# In this notebook we will walk through time series forecasting using XGBoost. The data we will be using is hourly energy consumption.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error
plt.style.use('fivethirtyeight')

# %% [markdown]
# # Data
# The data we will be using is hourly power consumption data from PJM. Energy consumtion has some unique charachteristics. It will be interesting to see how prophet picks them up.
#
# Pulling the `PJM East` which has data from 2002-2018 for the entire east region.

# %%
pjme = pd.read_csv('/Users/christopherkindl/working/start-hack-2021/01_ml/AEP_hourly.csv', index_col=[0], parse_dates=[0])

# %%
color_pal = ["#F8766D", "#D39200", "#93AA00", "#00BA38", "#00C19F", "#00B9E3", "#619CFF", "#DB72FB"]
_ = pjme.plot(style='.', figsize=(15,5), color=color_pal[0], title='PJM East')

# %% [markdown]
# # Train/Test Split
# Cut off the data after 2015 to use as our validation set.

# %%
split_date = '01-Jan-2015'
pjme_train = pjme.loc[pjme.index <= split_date].copy()
pjme_test = pjme.loc[pjme.index > split_date].copy()

# %%
pjme_test = pjme_test.rename(columns={'AEP_MW': 'PJME_MW'}) 
pjme_train = pjme_train.rename(columns={'AEP_MW': 'PJME_MW'})

# %%
_ = pjme_test \
    .rename(columns={'PJME_MW': 'TEST SET'}) \
    .join(pjme_train.rename(columns={'PJME_MW': 'TRAINING SET'}), how='outer') \
    .plot(figsize=(15,5), title='PJM East', style='.')

# %% [markdown]
# # Create Time Series Features

# %%
def create_features(df, label=None):
    """
    Creates time series features from datetime index
    """
    df['date'] = df.index
    df['hour'] = df['date'].dt.hour
    df['dayofweek'] = df['date'].dt.dayofweek
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['weekofyear'] = df['date'].dt.weekofyear
    
    X = df[['hour','dayofweek','quarter','month','year',
           'dayofyear','dayofmonth','weekofyear']]
    if label:
        y = df[label]
        return X, y
    return X

# %%
X_train, y_train = create_features(pjme_train, label='PJME_MW')
X_test, y_test = create_features(pjme_test, label='PJME_MW')
# Out:
# <ipython-input-10-568ff9107aea>:13: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['weekofyear'] = df['date'].dt.weekofyear

# %% [markdown]
# # Create XGBoost Model

# %%
reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=True) # Change verbose to True if you want to see it train
# Out:
# [0]	validation_0-rmse:11222.92285	validation_1-rmse:10311.86621
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 50 rounds.
# [1]	validation_0-rmse:7931.28760	validation_1-rmse:7034.17041
# [2]	validation_0-rmse:5650.31934	validation_1-rmse:4850.94141
# [3]	validation_0-rmse:4082.41943	validation_1-rmse:3455.44214
# [4]	validation_0-rmse:3020.19116	validation_1-rmse:2532.72485
# [5]	validation_0-rmse:2314.29053	validation_1-rmse:1984.89587
# [6]	validation_0-rmse:1857.17444	validation_1-rmse:1728.25195
# [7]	validation_0-rmse:1586.59839	validation_1-rmse:1614.13782
# [8]	validation_0-rmse:1401.88831	validation_1-rmse:1616.37952
# [9]	validation_0-rmse:1307.86414	validation_1-rmse:1613.73096
# [10]	validation_0-rmse:1226.42908	validation_1-rmse:1631.92468
# [11]	validation_0-rmse:1177.13428	validation_1-rmse:1645.59924
# [12]	validation_0-rmse:1154.63831	validation_1-rmse:1657.50989
# [13]	validation_0-rmse:1122.59436	validation_1-rmse:1667.47034
# [14]	validation_0-rmse:1110.03760	validation_1-rmse:1670.05750
# [15]	validation_0-rmse:1090.36926	validation_1-rmse:1678.60840
# [16]	validation_0-rmse:1082.27502	validation_1-rmse:1682.06580
# [17]	validation_0-rmse:1065.39221	validation_1-rmse:1677.07373
# [18]	validation_0-rmse:1048.55896	validation_1-rmse:1682.37207
# [19]	validation_0-rmse:1043.61023	validation_1-rmse:1687.10254
# [20]	validation_0-rmse:1020.17188	validation_1-rmse:1691.50940
# [21]	validation_0-rmse:1014.04767	validation_1-rmse:1689.30225
# [22]	validation_0-rmse:1010.97473	validation_1-rmse:1691.65613
# [23]	validation_0-rmse:1003.91406	validation_1-rmse:1688.86829
# [24]	validation_0-rmse:998.19806	validation_1-rmse:1689.26477
# [25]	validation_0-rmse:988.48291	validation_1-rmse:1710.44653
# [26]	validation_0-rmse:982.90070	validation_1-rmse:1708.50195
# [27]	validation_0-rmse:970.08643	validation_1-rmse:1721.34570
# [28]	validation_0-rmse:966.44873	validation_1-rmse:1720.45642
# [29]	validation_0-rmse:951.36639	validation_1-rmse:1739.85608
# [30]	validation_0-rmse:938.95941	validation_1-rmse:1752.06299
# [31]	validation_0-rmse:932.86060	validation_1-rmse:1759.03919
# [32]	validation_0-rmse:927.05249	validation_1-rmse:1759.51062
# [33]	validation_0-rmse:924.98987	validation_1-rmse:1760.78625
# [34]	validation_0-rmse:921.10791	validation_1-rmse:1759.07812
# [35]	validation_0-rmse:915.15656	validation_1-rmse:1763.78821
# [36]	validation_0-rmse:906.76886	validation_1-rmse:1767.53979
# [37]	validation_0-rmse:904.67377	validation_1-rmse:1768.76099
# [38]	validation_0-rmse:894.47656	validation_1-rmse:1788.97937
# [39]	validation_0-rmse:889.44318	validation_1-rmse:1790.75989
# [40]	validation_0-rmse:888.21649	validation_1-rmse:1791.45740
# [41]	validation_0-rmse:886.69788	validation_1-rmse:1794.00818
# [42]	validation_0-rmse:880.82465	validation_1-rmse:1791.66467
# [43]	validation_0-rmse:878.15143	validation_1-rmse:1791.99182
# [44]	validation_0-rmse:869.68829	validation_1-rmse:1799.51013
# [45]	validation_0-rmse:865.69086	validation_1-rmse:1800.34680
# [46]	validation_0-rmse:857.99457	validation_1-rmse:1800.66394
# [47]	validation_0-rmse:852.50342	validation_1-rmse:1806.87549
# [48]	validation_0-rmse:847.47119	validation_1-rmse:1814.09949
# [49]	validation_0-rmse:838.43250	validation_1-rmse:1816.49158
# [50]	validation_0-rmse:832.61688	validation_1-rmse:1821.87805
# [51]	validation_0-rmse:829.91583	validation_1-rmse:1820.08032
# [52]	validation_0-rmse:828.42853	validation_1-rmse:1820.41211
# [53]	validation_0-rmse:826.76691	validation_1-rmse:1821.76025
# [54]	validation_0-rmse:819.74817	validation_1-rmse:1827.69885
# [55]	validation_0-rmse:817.92981	validation_1-rmse:1828.69727
# [56]	validation_0-rmse:811.02771	validation_1-rmse:1833.29175
# [57]	validation_0-rmse:807.56854	validation_1-rmse:1831.79846
# [58]	validation_0-rmse:803.25879	validation_1-rmse:1833.32739
# [59]	validation_0-rmse:800.05096	validation_1-rmse:1838.62280
# Stopping. Best iteration:
# [9]	validation_0-rmse:1307.86414	validation_1-rmse:1613.73096
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# ## Feature Importances
# Feature importance is a great way to get a general idea about which features the model is relying on most to make the prediction. This is a metric that simply sums up how many times each feature is split on.
#
# We can see that the day of year was most commonly used to split trees, while hour and year came in next. Quarter has low importance due to the fact that it could be created by different dayofyear splits.

# %%
_ = plot_importance(reg, height=0.9)

# %% [markdown]
# # Forecast on Test Set

# %%
pjme_test['MW_Prediction'] = reg.predict(X_test)
pjme_all = pd.concat([pjme_test, pjme_train], sort=False)

# %%
_ = pjme_all[['PJME_MW','MW_Prediction']].plot(figsize=(15, 5))

# %% [markdown]
# # Look at first month of predictions

# %%
# Plot the forecast with the actuals
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
_ = pjme_all[['MW_Prediction','PJME_MW']].plot(ax=ax,
                                              style=['-','.'])
ax.set_xbound(lower='01-01-2015', upper='02-01-2015')
ax.set_ylim(0, 60000)
plot = plt.suptitle('January 2015 Forecast vs Actuals')

# %%
# Plot the forecast with the actuals
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
_ = pjme_all[['MW_Prediction','PJME_MW']].plot(ax=ax,
                                              style=['-','.'])
ax.set_xbound(lower='01-01-2015', upper='01-08-2015')
ax.set_ylim(0, 60000)
plot = plt.suptitle('First Week of January Forecast vs Actuals')

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
_ = pjme_all[['MW_Prediction','PJME_MW']].plot(ax=ax,
                                              style=['-','.'])
ax.set_ylim(0, 60000)
ax.set_xbound(lower='07-01-2015', upper='07-08-2015')
plot = plt.suptitle('First Week of July Forecast vs Actuals')

# %% [markdown]
# # Error Metrics On Test Set
# Our RMSE error is 13780445
# Our MAE error is 2848.89
# Our MAPE error is 8.9%

# %%
mean_squared_error(y_true=pjme_test['PJME_MW'],
                   y_pred=pjme_test['MW_Prediction'])
# Out:
# 2604129.5553274993

# %%
mean_absolute_error(y_true=pjme_test['PJME_MW'],
                   y_pred=pjme_test['MW_Prediction'])
# Out:
# 1237.3640072963715

# %% [markdown]
# I like using mean absolute percent error because it gives an easy to interperate percentage showing how off the predictions are.
# MAPE isn't included in sklearn so we need to use a custom function.

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(y_true=pjme_test['PJME_MW'],
                   y_pred=pjme_test['MW_Prediction'])

# %% [markdown]
# # Look at Worst and Best Predicted Days

# %%
pjme_test['error'] = pjme_test['PJME_MW'] - pjme_test['MW_Prediction']
pjme_test['abs_error'] = pjme_test['error'].apply(np.abs)
error_by_day = pjme_test.groupby(['year','month','dayofmonth']) \
    .mean()[['PJME_MW','MW_Prediction','error','abs_error']]

# %%
# Over forecasted days
error_by_day.sort_values('error', ascending=True).head(10)
# Out:
#                             PJME_MW  MW_Prediction        error    abs_error
# year month dayofmonth
# 2017 1     22          12295.541667   16617.234375 -4321.693319  4321.693319
#            21          12891.375000   16997.955078 -4106.580526  4106.580526
#      2     23          13437.333333   17466.052734 -4028.720256  4028.720256
#      1     23          14428.125000   18355.421875 -3927.295898  3927.295898
#      2     24          13111.625000   17027.525391 -3915.900187  3915.900187
#            22          13582.750000   17466.052734 -3883.303589  3883.303589
# 2018 1     22          14509.750000   18355.421875 -3845.670898  3845.670898
# 2015 12    25          11078.041667   14744.424805 -3666.382731  3666.382731
# 2017 1     25          14862.458333   18526.003906 -3663.545410  3663.545410
# 2016 7     4           12048.000000   15698.821289 -3650.821615  3650.821615

# %% [markdown]
# Notice anything about the over forecasted days?
# - #1 worst day - July 4th, 2016 - is a holiday.
# - #3 worst day - December 25, 2015 - Christmas
# - #5 worst day - July 4th, 2016 - is a holiday.
# Looks like our model may benefit from adding a holiday indicator.

# %%
# Worst absolute predicted days
error_by_day.sort_values('abs_error', ascending=False).head(10)

# %% [markdown]
# The best predicted days seem to be a lot of october (not many holidays and mild weather) Also early may

# %%
# Best predicted days
error_by_day.sort_values('abs_error', ascending=True).head(10)

# %% [markdown]
# # Plotting some best/worst predicted days

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(10)
_ = pjme_all[['MW_Prediction','PJME_MW']].plot(ax=ax,
                                              style=['-','.'])
ax.set_ylim(0, 60000)
ax.set_xbound(lower='08-13-2016', upper='08-14-2016')
plot = plt.suptitle('Aug 13, 2016 - Worst Predicted Day')

# %% [markdown]
# This one is pretty impressive. SPOT ON!

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(10)
_ = pjme_all[['MW_Prediction','PJME_MW']].plot(ax=ax,
                                              style=['-','.'])
ax.set_ylim(0, 60000)
ax.set_xbound(lower='10-03-2016', upper='10-04-2016')
plot = plt.suptitle('Oct 3, 2016 - Best Predicted Day')

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(10)
_ = pjme_all[['MW_Prediction','PJME_MW']].plot(ax=ax,
                                              style=['-','.'])
ax.set_ylim(0, 60000)
ax.set_xbound(lower='08-13-2016', upper='08-14-2016')
plot = plt.suptitle('Aug 13, 2016 - Worst Predicted Day')

# %% [markdown]
# # Up next?
# - Add Lag variables
# - Add holiday indicators.
# - Add weather data source.
